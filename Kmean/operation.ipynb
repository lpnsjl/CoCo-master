# %%
from sklearn.datasets import make_blobs
from sklearn.preprocessing import StandardScaler
from model import *

# %%
# 获取数据
centers = [[1, 1], [-1, -1], [1, -1]]
X, labels_true = make_blobs(n_samples=750, centers=centers, cluster_std=0.4, random_state=0)
X = StandardScaler().fit_transform(X)

# %%
# kmeans聚类
labels, loss, k = kMeans(X, 3)
# Out:
# centroid_0: [ 0.6954587  -0.64442334]
# centroid_1: [0.62260555 1.3172598 ]
# centroid_2: [-1.30266211 -0.65704205]
# loss: 0.4724288256301021
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-b79a3c3a6b7a> in <module>()
#       1 # kmeans聚类
# ----> 2 labels, loss, k = kMeans(X, 3)
#
# ValueError: not enough values to unpack (expected 3, got 2)

# %%
# 展现聚类结果
show_cluster_result(X, labels, k)
